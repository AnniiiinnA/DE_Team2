# %%
import pandas as pd

# %%
task_df = pd.read_csv("full_pilot_data/data_exp_226813-vall_tasks.csv")

# %%
task_df
# Out:
#      Event Index  UTC Timestamp     UTC Date and Time  Local Timestamp  \
# 0             ﻿1  1746992751690  11/05/2025, 19:45:51    1746974751690
# 1              2  1746992785545  11/05/2025, 19:46:25    1746974785545
# 2              3  1746992798626  11/05/2025, 19:46:38    1746974798626
# 3              4  1746992822826  11/05/2025, 19:47:02    1746974822826
# 4              5  1746992822827  11/05/2025, 19:47:02    1746974822827
# ...          ...            ...                   ...              ...
# 4139         203  1747423664912  16/05/2025, 19:27:44    1747398464912
# 4140         204  1747423664912  16/05/2025, 19:27:44    1747398464912
# 4141         205  1747423664913  16/05/2025, 19:27:44    1747398464913
# 4142         206  1747423664914  16/05/2025, 19:27:44    1747398464914
# 4143         207  1747423664915  16/05/2025, 19:27:44    1747398464915
#
#       Local Timezone   Local Date and Time  Experiment ID  Experiment Version  \
# 0                 -5  11/05/2025, 09:45:51         226813                   7
# 1                 -5  11/05/2025, 09:46:25         226813                   7
# 2                 -5  11/05/2025, 09:46:38         226813                   7
# 3                 -5  11/05/2025, 09:47:02         226813                   7
# 4                 -5  11/05/2025, 09:47:02         226813                   7
# ...              ...                   ...            ...                 ...
# 4139              -7  16/05/2025, 05:27:44         226813                   8
# 4140              -7  16/05/2025, 05:27:44         226813                   8
# 4141              -7  16/05/2025, 05:27:44         226813                   8
# 4142              -7  16/05/2025, 05:27:44         226813                   8
# 4143              -7  16/05/2025, 05:27:44         226813                   8
#
#      Tree Node Key  Repeat Key  ...  Spreadsheet: Product  \
# 0        task-fsrg         NaN  ...                   NaN
# 1        task-fsrg         NaN  ...                   NaN
# 2        task-fsrg         NaN  ...        presentbox.jpg
# 3        task-fsrg         NaN  ...        presentbox.jpg
# 4        task-fsrg         NaN  ...        presentbox.jpg
# ...            ...         ...  ...                   ...
# 4139     task-fsrg         NaN  ...    Microwave Oven.png
# 4140     task-fsrg         NaN  ...    Microwave Oven.png
# 4141     task-fsrg         NaN  ...    Microwave Oven.png
# 4142     task-fsrg         NaN  ...    Microwave Oven.png
# 4143     task-fsrg         NaN  ...                   NaN
#
#                                   Spreadsheet: Question  \
# 0                                                   NaN
# 1                                                   NaN
# 2     You need to buy 2 of the same product. Which o...
# 3     You need to buy 2 of the same product. Which o...
# 4     You need to buy 2 of the same product. Which o...
# ...                                                 ...
# 4139  You need to buy 2 of the same product. Which o...
# 4140  You need to buy 2 of the same product. Which o...
# 4141  You need to buy 2 of the same product. Which o...
# 4142  You need to buy 2 of the same product. Which o...
# 4143                                                NaN
#
#               Spreadsheet: Discount 1        Spreadsheet: Discount 2  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2     $10 (Deal: buy 1 get 1 30% off)             $10 (Deal: $3 off)
# 3     $10 (Deal: buy 1 get 1 30% off)             $10 (Deal: $3 off)
# 4     $10 (Deal: buy 1 get 1 30% off)             $10 (Deal: $3 off)
# ...                               ...                            ...
# 4139            $300 (Deal: now $240)  $480 (Deal: buy 1 get 1 free)
# 4140            $300 (Deal: now $240)  $480 (Deal: buy 1 get 1 free)
# 4141            $300 (Deal: now $240)  $480 (Deal: buy 1 get 1 free)
# 4142            $300 (Deal: now $240)  $480 (Deal: buy 1 get 1 free)
# 4143                              NaN                            NaN
#
#       Spreadsheet: Discount 3  Spreadsheet: Discount 4 Spreadsheet: correct  \
# 0                         NaN                      NaN                  NaN
# 1                         NaN                      NaN                  NaN
# 2         $10 (Deal: 10% off)       $10 (Deal: now $8)                  NaN
# 3         $10 (Deal: 10% off)       $10 (Deal: now $8)                  NaN
# 4         $10 (Deal: 10% off)       $10 (Deal: now $8)                  NaN
# ...                       ...                      ...                  ...
# 4139     $300 (Deal: $60 off)     $300 (Deal: 20% off)                  NaN
# 4140     $300 (Deal: $60 off)     $300 (Deal: 20% off)                  NaN
# 4141     $300 (Deal: $60 off)     $300 (Deal: 20% off)                  NaN
# 4142     $300 (Deal: $60 off)     $300 (Deal: 20% off)                  NaN
# 4143                      NaN                      NaN                  NaN
#
#      Spreadsheet: rand_flag Manipulation: Spreadsheet branch-8m3o
# 0                       NaN                       NaN     consent
# 1                       NaN                       NaN     consent
# 2                       NaN                       NaN     consent
# 3                       NaN                       NaN     consent
# 4                       NaN                       NaN     consent
# ...                     ...                       ...         ...
# 4139                   main                       NaN     consent
# 4140                   main                       NaN     consent
# 4141                   main                       NaN     consent
# 4142                   main                       NaN     consent
# 4143                    NaN                       NaN     consent
#
# [4144 rows x 58 columns]

# %%
mask = task_df["Response Type"]=="info"
df = task_df[mask]

# %%
import pandas as pd
import re

# Sample DataFrame
# df = pd.read_csv('your_data.csv')  # Your actual DataFrame
# Example:
# df = pd.DataFrame({'Response': ['Some text', 'Recording Uploaded: https://example.com/abc', 'No URL here']})

# Define a regex pattern to match the URL
pattern = r"Recording Uploaded:\s*(https?://\S+)"

# Apply regex to extract URLs
urls = df['Response'].str.extract(pattern)

# Drop rows with NaN (no URL found)
url_list = urls.dropna()[0].tolist()

print(url_list)
# Out:
# ['https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-1-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-2-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-3-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-4-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-5-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-6-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-7-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-8-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-9-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-10-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-12-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-13-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-14-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-15-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-16-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-17-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-1-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-2-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-3-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-4-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-5-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-6-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-7-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-8-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-9-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-10-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-12-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-13-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-14-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-15-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-16-2.csv', 'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-17-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-1-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-2-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-3-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-4-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-5-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-6-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-7-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-8-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-9-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-10-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-12-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-13-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-14-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-15-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-16-2.csv', 'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-17-2. ...

# %%
url_list
# Out:
# ['https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46069871?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46071022?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46073891?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46074382?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46097784?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46144990?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151473?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46151542?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152300?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46152529?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46195155?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46219300?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46227786?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46228740?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46230592?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46231595?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46251926?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46108619?filename=mousetracking-17-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-1-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-2-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-3-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-4-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-5-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-6-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-7-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-8-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-9-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-10-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-12-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-13-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-14-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-15-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-16-2.csv',
#  'https://app.gorilla.sc/uploads/schedule/46265160?filename=mousetracking-17-2.csv']

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = url_list[0]
url
# Out:
# 'https://app.gorilla.sc/uploads/schedule/46069857?filename=mousetracking-1-2.csv'

# %%
r = requests.get(url)
html_soup = BeautifulSoup(r.text, 'html.parser')

# %%
html_soup
# Out:
# {"success":false,"message":"Error getting experiment info"}

# %% [markdown]
# # You can't use urls, so I'm using individual csvs now

# %%
import pandas as pd

pattern = r"Recording Uploaded:\s*(226813\S+)"

# Apply regex to extract URLs
files = df['Response'].str.extract(pattern)

# Replace "/" with "-" in the extracted strings
files[0] = files[0].str.replace("/", "-", regex=False)

# Drop rows with NaN (no URL found) and convert to list
filelist = files.dropna()[0].tolist()

print(filelist)
# Out:
# ['226813-7-13397659-task-fsrg-46069857-mousetracking-1-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-2-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-3-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-4-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-5-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-6-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-7-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-8-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-9-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-10-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-12-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-13-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-14-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-15-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-16-2.csv', '226813-7-13397659-task-fsrg-46069857-mousetracking-17-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-1-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-2-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-3-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-4-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-5-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-6-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-7-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-8-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-9-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-10-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-12-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-13-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-14-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-15-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-16-2.csv', '226813-7-13397665-task-fsrg-46069871-mousetracking-17-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-1-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-2-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-3-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-4-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-5-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-6-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-7-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-8-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-9-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-10-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-12-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-13-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-14-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-15-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-16-2.csv', '226813-8-13397950-task-fsrg-46071022-mousetracking-17-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-1-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-2-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-3-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-4-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-5-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-6-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-7-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-8-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-9-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-10-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-12-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-13-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-14-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-15-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-16-2.csv', '226813-8-13398525-task-fsrg-46073891-mousetracking-17-2.csv', '22 ...

# %%
filelist
# Out:
# ['226813-7-13397659-task-fsrg-46069857-mousetracking-1-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-2-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-3-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-4-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-5-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-6-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-7-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-8-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-9-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-10-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-12-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-13-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-14-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-15-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-16-2.csv',
#  '226813-7-13397659-task-fsrg-46069857-mousetracking-17-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-1-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-2-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-3-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-4-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-5-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-6-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-7-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-8-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-9-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-10-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-12-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-13-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-14-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-15-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-16-2.csv',
#  '226813-7-13397665-task-fsrg-46069871-mousetracking-17-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-1-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-2-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-3-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-4-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-5-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-6-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-7-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-8-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-9-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-10-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-12-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-13-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-14-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-15-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-16-2.csv',
#  '226813-8-13397950-task-fsrg-46071022-mousetracking-17-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-1-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-2-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-3-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-4-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-5-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-6-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-7-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-8-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-9-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-10-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-12-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-13-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-14-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-15-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-16-2.csv',
#  '226813-8-13398525-task-fsrg-46073891-mousetracking-17-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-1-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-2-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-3-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-4-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-5-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-6-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-7-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-8-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-9-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-10-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-12-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-13-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-14-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-15-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-16-2.csv',
#  '226813-8-13398617-task-fsrg-46074382-mousetracking-17-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-1-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-2-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-3-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-4-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-5-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-6-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-7-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-8-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-9-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-10-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-12-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-13-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-14-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-15-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-16-2.csv',
#  '226813-8-13401275-task-fsrg-46097784-mousetracking-17-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-1-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-2-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-3-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-4-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-5-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-6-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-7-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-8-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-9-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-10-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-12-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-13-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-14-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-15-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-16-2.csv',
#  '226813-8-13414503-task-fsrg-46144990-mousetracking-17-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-1-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-2-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-3-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-4-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-5-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-6-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-7-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-8-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-9-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-10-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-12-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-13-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-14-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-15-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-16-2.csv',
#  '226813-8-13415449-task-fsrg-46151473-mousetracking-17-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-1-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-2-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-3-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-4-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-5-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-6-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-7-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-8-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-9-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-10-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-12-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-13-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-14-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-15-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-16-2.csv',
#  '226813-8-13415450-task-fsrg-46151542-mousetracking-17-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-1-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-2-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-3-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-4-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-5-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-6-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-7-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-8-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-9-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-10-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-12-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-13-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-14-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-15-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-16-2.csv',
#  '226813-8-13415567-task-fsrg-46152300-mousetracking-17-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-1-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-2-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-3-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-4-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-5-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-6-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-7-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-8-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-9-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-10-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-12-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-13-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-14-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-15-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-16-2.csv',
#  '226813-8-13415604-task-fsrg-46152529-mousetracking-17-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-1-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-2-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-3-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-4-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-5-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-6-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-7-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-8-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-9-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-10-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-12-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-13-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-14-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-15-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-16-2.csv',
#  '226813-8-13425616-task-fsrg-46195155-mousetracking-17-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-1-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-2-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-3-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-4-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-5-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-6-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-7-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-8-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-9-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-10-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-12-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-13-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-14-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-15-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-16-2.csv',
#  '226813-8-13430110-task-fsrg-46219300-mousetracking-17-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-1-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-2-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-3-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-4-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-5-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-6-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-7-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-8-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-9-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-10-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-12-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-13-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-14-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-15-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-16-2.csv',
#  '226813-8-13432012-task-fsrg-46227786-mousetracking-17-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-1-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-2-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-3-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-4-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-5-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-6-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-7-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-8-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-9-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-10-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-12-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-13-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-14-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-15-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-16-2.csv',
#  '226813-8-13432196-task-fsrg-46228740-mousetracking-17-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-1-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-2-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-3-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-4-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-5-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-6-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-7-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-8-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-9-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-10-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-12-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-13-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-14-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-15-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-16-2.csv',
#  '226813-8-13432989-task-fsrg-46230592-mousetracking-17-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-1-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-2-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-3-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-4-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-5-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-6-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-7-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-8-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-9-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-10-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-12-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-13-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-14-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-15-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-16-2.csv',
#  '226813-8-13433652-task-fsrg-46231595-mousetracking-17-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-1-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-2-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-3-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-4-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-5-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-6-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-7-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-8-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-9-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-10-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-12-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-13-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-14-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-15-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-16-2.csv',
#  '226813-8-13441531-task-fsrg-46251926-mousetracking-17-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-1-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-2-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-3-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-4-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-5-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-6-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-7-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-8-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-9-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-10-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-12-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-13-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-14-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-15-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-16-2.csv',
#  '226813-8-13406543-task-fsrg-46108619-mousetracking-17-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-1-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-2-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-3-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-4-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-5-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-6-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-7-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-8-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-9-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-10-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-12-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-13-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-14-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-15-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-16-2.csv',
#  '226813-8-13444141-task-fsrg-46265160-mousetracking-17-2.csv']

# %%
df = pd.read_csv(f"full_pilot_data/uploads/{filelist[0]}")
df.head()
# Out:
#    Experiment ID  Experiment Version Tree Node Key  Schedule ID  \
# 0         226813                   7     task-fsrg     46069857
# 1         226813                   7     task-fsrg     46069857
# 2         226813                   7     task-fsrg     46069857
# 3         226813                   7     task-fsrg     46069857
# 4         226813                   7     task-fsrg     46069857
#
#    Participant Private ID   Spreadsheet  Spreadsheet Index         Display  \
# 0                13397659  Spreadsheet1                  1  Practice Trial
# 1                13397659  Spreadsheet1                  1  Practice Trial
# 2                13397659  Spreadsheet1                  1  Practice Trial
# 3                13397659  Spreadsheet1                  1  Practice Trial
# 4                13397659  Spreadsheet1                  1  Practice Trial
#
#    Trial Count   Screen   ... Elapsed  Type      Name   Unique ID  \
# 0            1  Screen 1  ...     0.0  zone     Image  object-300
# 1            1  Screen 1  ...     0.0  zone     Image  object-301
# 2            1  Screen 1  ...     0.0  zone     Image  object-302
# 3            1  Screen 1  ...     0.0  zone     Image  object-303
# 4            1  Screen 1  ...     0.0  zone  Question  object-304
#
#    X Normalised Y Normalised W Normalised H Normalised  X Raw  Y Raw
# 0      0.809795     0.531384     0.130410     0.173879      0      0
# 1      0.559795     0.531384     0.130410     0.173879      0      0
# 2      0.309795     0.531384     0.130410     0.173879      0      0
# 3      0.059795     0.531384     0.130410     0.173879      0      0
# 4      0.083269     0.944273     0.833462     0.277434      0      0
#
# [5 rows x 24 columns]

# %%
mask = df["Type"] == "mouse"
df = df[mask][["X Normalised", "Y Normalised"]]
df
# Out:
# Empty DataFrame
# Columns: [X Normalised, Y Normalised]
# Index: []

# %%
import math

def get_mouse_distance(df):
    '''
    Gets distance mouse traveled in a single trial from df
    '''

    mask = df["Type"] == "mouse"
    df = df[mask][["X Normalised", "Y Normalised"]]
    distance = 0
    for i in range(df.shape[0]-1):
        square =  (df.iloc[i] - df.iloc[i+1]) ** 2
        distance += math.sqrt(square.sum())
    return distance

# %%
import math

def get_mouse_path_efficiency(df):
    '''
    Calculates path efficiency: 
    (euclidean distance from start to end) / (total distance traveled)
    '''
    mask = df["Type"] == "mouse"
    coords = df[mask][["X Normalised", "Y Normalised"]].reset_index(drop=True)

    if coords.shape[0] < 2:
        return None  # Not enough data points to compute efficiency

    # Total path distance
    distance = 0
    for i in range(coords.shape[0] - 1):
        square = (coords.iloc[i] - coords.iloc[i+1]) ** 2
        distance += math.sqrt(square.sum())

    # Euclidean distance from start to end
    start = coords.iloc[0]
    end = coords.iloc[-1]
    straight_line = math.sqrt(((start - end) ** 2).sum())

    if distance == 0:
        return None  # Avoid division by zero

    efficiency = straight_line / distance
    return efficiency

# %%
df = pd.read_csv(f"full_pilot_data/uploads/{filelist[0]}")

get_mouse_distance(df)
# Out:
# 0.9254515625977147

# %%
distances_main = []
efficiency_main = []
distances_fatigue = []
efficiency_fatigue = []
for file in filelist:
    df = pd.read_csv(f"full_pilot_data/uploads/{file}")
    if "Main" in df["Display"][0]:
        distances_main.append(get_mouse_distance(df))
        efficiency_main.append(get_mouse_path_efficiency(df))
    elif "Fatigue" in df["Display"][0]:
        distances_fatigue.append(get_mouse_distance(df))
        efficiency_fatigue.append(get_mouse_path_efficiency(df))

# %%
fatigue_trials = pd.read_csv("processed_pilot_data/fatigue_trials.csv")

# %%
main_trials = pd.read_csv("processed_pilot_data/main_trials.csv")

# %%
main_trials
# Out:
#      Participant ID           Display     Spreadsheet: Product  \
# 0          13397659  3 Discounts Main          Tablet Case.png
# 1          13397659  3 Discounts Main        Phone Charger.png
# 2          13397659  4 Discounts Main            DSLR Lens.png
# 3          13397659  4 Discounts Main                 Sofa.png
# 4          13397659  2 Discounts Main         Skincare Kit.png
# ..              ...               ...                      ...
# 115        13444141  2 Discounts Main              Earbuds.png
# 116        13444141  2 Discounts Main  Mechanical Keyboard.png
# 117        13444141  3 Discounts Main            Desk Lamp.png
# 118        13444141  4 Discounts Main            DSLR Lens.png
# 119        13444141  4 Discounts Main       Microwave Oven.png
#
#                           Response    Position  Reaction Time       Deal Type  \
# 0              $25 (Deal: 10% off)  Position 1        18598.5  Percentage off
# 1              $15 (Deal: 10% off)  Position 3         6847.8  Percentage off
# 2    $960 (Deal: buy 1 get 1 free)  Position 1        13848.7            BOGO
# 3           $1000 (Deal: $200 off)  Position 3        13065.3      Dollar off
# 4              $90 (Deal: 15% off)  Position 1        14565.8  Percentage off
# ..                             ...         ...            ...             ...
# 115            $80 (Deal: 10% off)  Position 2        17493.1  Percentage off
# 116           $120 (Deal: 10% off)  Position 1        11680.7  Percentage off
# 117            $40 (Deal: now $36)  Position 2        12262.0       Now price
# 118          $600 (Deal: now $480)  Position 4        60085.4       Now price
# 119          $300 (Deal: now $240)  Position 1        39566.1       Now price
#
#      Likely to buy  Confident in choice  Likely to change  \
# 0                3                    1                 7
# 1                1                    5                 7
# 2                2                    5                 6
# 3                2                    5                 6
# 4                5                    6                 6
# ..             ...                  ...               ...
# 115              4                    5                 6
# 116              3                    4                 6
# 117              4                    6                 6
# 118              1                    4                 5
# 119              2                    5                 6
#
#      Attention Check Response  \
# 0                           3
# 1                           3
# 2                           4
# 3                           4
# 4                           2
# ..                        ...
# 115                         2
# 116                         2
# 117                         2
# 118                         3
# 119                         3
#
#                                           Why Response
# 0             It's all the same, but 10% looks bigger.
# 1           All the same price so I chose the cheapest
# 2        It saves more so I can sell the duplicate one
# 3             Too big so I can't store it and sell it.
# 4         15 looks bigger though they are all the same
# ..                                                 ...
# 115  I chose the percentage in case this could pote...
# 116  Same reason as the headphones, I would hope th...
# 117  I would hope I can apply another discount if a...
# 118  I avoided BOGO thinking in case I need to retu...
# 119  Again, I avoided the BOGO option for returning...
#
# [120 rows x 12 columns]

# %%
fatigue_trials
# Out:
#      Participant ID              Display       Spreadsheet: Product  \
# 0          13397659  3 Discounts Fatigue  Home Espresso Machine.png
# 1          13397659  2 Discounts Fatigue         Leather Wallet.png
# 2          13397659  2 Discounts Fatigue       Wireless Charger.png
# 3          13397659  2 Discounts Fatigue        Fitness Tracker.png
# 4          13397659  3 Discounts Fatigue      Designer Backpack.png
# ..              ...                  ...                        ...
# 175        13444141  4 Discounts Fatigue          Running Shoes.png
# 176        13444141  4 Discounts Fatigue      Bluetooth Speaker.png
# 177        13444141  4 Discounts Fatigue        Electric Kettle.png
# 178        13444141  2 Discounts Fatigue        Fitness Tracker.png
# 179        13444141  3 Discounts Fatigue  Home Espresso Machine.png
#
#                              Response    Position  Reaction Time   Deal Type  \
# 0                $350 (Deal: $50 off)  Position 3        13230.5  Dollar off
# 1                 $70 (Deal: now $58)  Position 2        13616.0   Now price
# 2                 $60 (Deal: now $45)  Position 2         8581.1   Now price
# 3                 $95 (Deal: now $80)  Position 2         7899.8   Now price
# 4                $180 (Deal: $20 off)  Position 1        27182.2  Dollar off
# ..                                ...         ...            ...         ...
# 175  $120 (Deal: buy 1 get 1 50% off)  Position 1        36930.5        BOGO
# 176      $90 (Deal: buy 1 get 1 free)  Position 3        32174.2        BOGO
# 177               $35 (Deal: now $29)  Position 2        48582.0   Now price
# 178               $95 (Deal: now $80)  Position 2        12384.3   Now price
# 179     $399 (Deal: buy 1 get 1 free)  Position 3        22429.2        BOGO
#
#     correct response  accuracy
# 0               BOGO     False
# 1          Now price      True
# 2          Now price      True
# 3          Now price      True
# 4          Now price     False
# ..               ...       ...
# 175             BOGO      True
# 176             BOGO      True
# 177        Now price      True
# 178        Now price      True
# 179             BOGO      True
#
# [180 rows x 9 columns]

# %%
main_trials["Distance"] = distances_main
main_trials["Efficiency"] = efficiency_main
fatigue_trials["Distance"] = distances_fatigue
fatigue_trials["Efficiency"] = efficiency_fatigue

# %%
main_trials
# Out:
#      Participant ID           Display     Spreadsheet: Product  \
# 0          13397659  3 Discounts Main          Tablet Case.png
# 1          13397659  3 Discounts Main        Phone Charger.png
# 2          13397659  4 Discounts Main            DSLR Lens.png
# 3          13397659  4 Discounts Main                 Sofa.png
# 4          13397659  2 Discounts Main         Skincare Kit.png
# ..              ...               ...                      ...
# 115        13444141  2 Discounts Main              Earbuds.png
# 116        13444141  2 Discounts Main  Mechanical Keyboard.png
# 117        13444141  3 Discounts Main            Desk Lamp.png
# 118        13444141  4 Discounts Main            DSLR Lens.png
# 119        13444141  4 Discounts Main       Microwave Oven.png
#
#                           Response    Position  Reaction Time       Deal Type  \
# 0              $25 (Deal: 10% off)  Position 1        18598.5  Percentage off
# 1              $15 (Deal: 10% off)  Position 3         6847.8  Percentage off
# 2    $960 (Deal: buy 1 get 1 free)  Position 1        13848.7            BOGO
# 3           $1000 (Deal: $200 off)  Position 3        13065.3      Dollar off
# 4              $90 (Deal: 15% off)  Position 1        14565.8  Percentage off
# ..                             ...         ...            ...             ...
# 115            $80 (Deal: 10% off)  Position 2        17493.1  Percentage off
# 116           $120 (Deal: 10% off)  Position 1        11680.7  Percentage off
# 117            $40 (Deal: now $36)  Position 2        12262.0       Now price
# 118          $600 (Deal: now $480)  Position 4        60085.4       Now price
# 119          $300 (Deal: now $240)  Position 1        39566.1       Now price
#
#      Likely to buy  Confident in choice  Likely to change  \
# 0                3                    1                 7
# 1                1                    5                 7
# 2                2                    5                 6
# 3                2                    5                 6
# 4                5                    6                 6
# ..             ...                  ...               ...
# 115              4                    5                 6
# 116              3                    4                 6
# 117              4                    6                 6
# 118              1                    4                 5
# 119              2                    5                 6
#
#      Attention Check Response  \
# 0                           3
# 1                           3
# 2                           4
# 3                           4
# 4                           2
# ..                        ...
# 115                         2
# 116                         2
# 117                         2
# 118                         3
# 119                         3
#
#                                           Why Response  Distance  Efficiency
# 0             It's all the same, but 10% looks bigger.  0.833028    0.347480
# 1           All the same price so I chose the cheapest  0.345875    0.815453
# 2        It saves more so I can sell the duplicate one  0.471964    0.822775
# 3             Too big so I can't store it and sell it.  0.887463    0.152630
# 4         15 looks bigger though they are all the same  0.822076    0.289742
# ..                                                 ...       ...         ...
# 115  I chose the percentage in case this could pote...  1.582616    0.116298
# 116  Same reason as the headphones, I would hope th...  1.582906    0.161930
# 117  I would hope I can apply another discount if a...  0.475784    0.074055
# 118  I avoided BOGO thinking in case I need to retu...  1.135310    0.317891
# 119  Again, I avoided the BOGO option for returning...  1.971569    0.208313
#
# [120 rows x 14 columns]

# %%
fatigue_trials
# Out:
#      Participant ID              Display       Spreadsheet: Product  \
# 0          13397659  3 Discounts Fatigue  Home Espresso Machine.png
# 1          13397659  2 Discounts Fatigue         Leather Wallet.png
# 2          13397659  2 Discounts Fatigue       Wireless Charger.png
# 3          13397659  2 Discounts Fatigue        Fitness Tracker.png
# 4          13397659  3 Discounts Fatigue      Designer Backpack.png
# ..              ...                  ...                        ...
# 175        13444141  4 Discounts Fatigue          Running Shoes.png
# 176        13444141  4 Discounts Fatigue      Bluetooth Speaker.png
# 177        13444141  4 Discounts Fatigue        Electric Kettle.png
# 178        13444141  2 Discounts Fatigue        Fitness Tracker.png
# 179        13444141  3 Discounts Fatigue  Home Espresso Machine.png
#
#                              Response    Position  Reaction Time   Deal Type  \
# 0                $350 (Deal: $50 off)  Position 3        13230.5  Dollar off
# 1                 $70 (Deal: now $58)  Position 2        13616.0   Now price
# 2                 $60 (Deal: now $45)  Position 2         8581.1   Now price
# 3                 $95 (Deal: now $80)  Position 2         7899.8   Now price
# 4                $180 (Deal: $20 off)  Position 1        27182.2  Dollar off
# ..                                ...         ...            ...         ...
# 175  $120 (Deal: buy 1 get 1 50% off)  Position 1        36930.5        BOGO
# 176      $90 (Deal: buy 1 get 1 free)  Position 3        32174.2        BOGO
# 177               $35 (Deal: now $29)  Position 2        48582.0   Now price
# 178               $95 (Deal: now $80)  Position 2        12384.3   Now price
# 179     $399 (Deal: buy 1 get 1 free)  Position 3        22429.2        BOGO
#
#     correct response  accuracy  Distance  Efficiency
# 0               BOGO     False  0.302701    0.988519
# 1          Now price      True  0.913395    0.256740
# 2          Now price      True  0.299518    0.749583
# 3          Now price      True  0.181786    0.994447
# 4          Now price     False  0.308391    0.866612
# ..               ...       ...       ...         ...
# 175             BOGO      True  4.630937    0.083625
# 176             BOGO      True  0.821315    0.210770
# 177        Now price      True  0.747202    0.250116
# 178        Now price      True  1.349462    0.161117
# 179             BOGO      True  1.095115    0.271728
#
# [180 rows x 11 columns]

# %% [markdown]
# # Analysis and Visualization

# %%
df = main_trials

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ANOVA with mouse distance
model = ols('Distance ~ C(Display)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq     df        F    PR(>F)
# C(Display)   23.935108    2.0  6.07426  0.003091
# Residual    230.514295  117.0      NaN       NaN

# %%
# ANOVA with mouse efficiency
model = ols('Efficiency ~ C(Display)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                sum_sq     df         F    PR(>F)
# C(Display)   0.072777    2.0  0.341475  0.711427
# Residual    12.467883  117.0       NaN       NaN

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Display', y='Distance', hue="Display")
plt.title('Mouse Distance by Display')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Display', y='Efficiency', hue="Display")
plt.title('Mouse Efficiency by Display')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
